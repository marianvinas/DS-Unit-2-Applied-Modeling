# %% [markdown]
# <a href="https://colab.research.google.com/github/marianvinas/DS-Unit-2-Applied-Modeling/blob/master/Marian_Vinas_LS_DS_232_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 2*
#
# ---
#
#
# # Wrangle ML datasets
#
# - [ ] Continue to clean and explore your data.
# - [ ] For the evaluation metric you chose, what score would you get just by guessing?
# - [ ] Can you make a fast, first model that beats guessing?
#
# **We recommend that you use your portfolio project dataset for all assignments this sprint.**
#
# **But if you aren't ready yet, or you want more practice, then use the New York City property sales dataset for today's assignment.** Follow the instructions below, to just keep a subset for the Tribeca neighborhood, and remove outliers or dirty data. [Here's a video walkthrough](https://youtu.be/pPWFw8UtBVg?t=584) you can refer to if you get stuck or want hints!
#
# - Data Source: [NYC OpenData: NYC Citywide Rolling Calendar Sales](https://data.cityofnewyork.us/dataset/NYC-Citywide-Rolling-Calendar-Sales/usep-8jbt)
# - Glossary: [NYC Department of Finance: Rolling Sales Data](https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page)

# %% [markdown]
# #New home sales dataset.

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://query.data.world/s/4bmd5zk5xyaeuvzdeqbd754m3lqg3l'
    # !pip install category_encoders==2.*
    # !pip install eli5

# %%
import pandas as pd
pd.options.display.max_columns = None
import pandas as pd
df = pd.read_csv('https://query.data.world/s/4bmd5zk5xyaeuvzdeqbd754m3lqg3l')

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split


df = df.dropna(subset=['BedroomAbvGr'])
df['Great'] = df['BedroomAbvGr'] >= 4

cardinality = df.select_dtypes(exclude='number').nunique()

high_cardinality_feat = cardinality[cardinality > 20].index.tolist()
df = df.drop(columns = high_cardinality_feat)
df = df.fillna('Missing')

train = df[df['YrSold'] <= 2016]
val = df[df['YrSold'] == 2007]
test = df[df['YrSold'] <= 2008]

target = 'Great'
features = train.columns.drop([target, 'YrSold'])
X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]

#pipeline = make_pipeline(
    #ce.ordinal.OrdinalEncoder(),
    #DecisionTreeClassifier(max_depth=5)
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)
pipeline.fit(X_train, y_train)
print(f'Validation accuracy: {pipeline.score(X_val, y_val)}')
# Out:
# Validation accuracy: 1.0

# %% [markdown]
# Your code starts here:

# %%
df['SalePrice'].value_counts()
# Out:
# 140000    20
# 135000    17
# 145000    14
# 155000    14
# 190000    13
#           ..
# 84900      1
# 424870     1
# 415298     1
# 62383      1
# 34900      1
# Name: SalePrice, Length: 663, dtype: int64

# %%
df.groupby('Id')['MoSold'].count().sort_values(ascending=False)
# Out:
# Id
# 1460    1
# 479     1
# 481     1
# 482     1
# 483     1
#        ..
# 976     1
# 977     1
# 978     1
# 979     1
# 1       1
# Name: MoSold, Length: 1460, dtype: int64

# %%
#most month Sold: 1460
# 6 sold in a month

# %%
df[df['Id'] == 1460]
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street    Alley LotShape  \
# 1459  1460          20       RL          75     9937   Pave  Missing      Reg
#
#      LandContour Utilities LotConfig LandSlope Condition1 Condition2 BldgType  \
# 1459         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 1459     1Story            5            6       1965          1965     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType MasVnrArea ExterQual  \
# 1459  CompShg     HdBoard     HdBoard       None          0        Gd
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 1459        TA     CBlock       TA       TA           No          BLQ
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 1459         830          LwQ         290        136         1256    GasA
#
#      HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 1459        Gd          Y      SBrkr      1256         0             0
#
#       GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 1459       1256             1             0         1         1             3
#
#       KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 1459             1          TA             6        Typ           0
#
#      FireplaceQu GarageType GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 1459     Missing     Attchd        1965          Fin           1         276
#
#      GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 1459         TA         TA          Y         736           68              0
#
#       3SsnPorch  ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  \
# 1459          0            0         0  Missing  Missing     Missing        0
#
#       MoSold  YrSold SaleType SaleCondition  SalePrice  Great
# 1459       6    2008       WD        Normal     147500  False

# %%
df.sample(20)
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street    Alley LotShape  \
# 129    130          20       RL          69     8973   Pave  Missing      Reg
# 512    513          20       RL          70     9100   Pave  Missing      Reg
# 474    475         120       RL          41     5330   Pave  Missing      Reg
# 402    403          30       RL          60    10200   Pave  Missing      Reg
# 407    408          70       RL          63    15576   Pave  Missing      Reg
# 82      83          20       RL          78    10206   Pave  Missing      Reg
# 1220  1221          20       RL          66     7800   Pave  Missing      IR1
# 568    569          50       RL          79    12327   Pave  Missing      IR1
# 336    337          20       RL          86    14157   Pave  Missing      IR1
# 1458  1459          20       RL          68     9717   Pave  Missing      Reg
# 1118  1119          80       RL          85    13825   Pave  Missing      Reg
# 647    648          20       RL          85    10452   Pave  Missing      IR1
# 1441  1442         120       RM     Missing     4426   Pave  Missing      Reg
# 186    187          80       RL     Missing     9947   Pave  Missing      IR1
# 1341  1342          20       RL          66    13695   Pave  Missing      Reg
# 1225  1226          80       RL          65    10482   Pave  Missing      Reg
# 1257  1258          30       RL          56     4060   Pave  Missing      Reg
# 532    533          20       RL          60     7200   Pave  Missing      Reg
# 1330  1331          20       RL          85    10000   Pave  Missing      Reg
# 580    581          20       RL     Missing    14585   Pave  Missing      IR1
#
#      LandContour Utilities LotConfig LandSlope Condition1 Condition2 BldgType  \
# 129          Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 512          Lvl    AllPub    Corner       Gtl      Feedr       Norm     1Fam
# 474          Lvl    AllPub    Inside       Gtl       Norm       Norm   TwnhsE
# 402          Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 407          Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 82           Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 1220         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 568          Low    AllPub    Inside       Mod       Norm       Norm     1Fam
# 336          HLS    AllPub    Corner       Gtl       Norm       Norm     1Fam
# 1458         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 1118         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 647          Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 1441         Lvl    AllPub    Inside       Gtl       Norm       Norm   TwnhsE
# 186          Lvl    AllPub   CulDSac       Gtl       Norm       Norm     1Fam
# 1341         Lvl    AllPub    Inside       Gtl       RRAe       Norm     1Fam
# 1225         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 1257         Lvl    AllPub    Corner       Gtl      Feedr       Norm     1Fam
# 532          Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 1330         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 580          Lvl    AllPub   CulDSac       Gtl       Norm       Norm     1Fam
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 129      1Story            5            7       1958          1991     Gable
# 512      1Story            5            5       1958          1958     Gable
# 474      1Story            8            5       2000          2000     Gable
# 402      1Story            5            8       1940          1997     Gable
# 407      2Story            6            7       1915          1976     Gable
# 82       1Story            8            5       2007          2007     Gable
# 1220     1Story            5            5       1964          1964     Gable
# 568      1.5Fin            8            8       1983          2009     Gable
# 336      1Story            9            5       2005          2006       Hip
# 1458     1Story            5            6       1950          1996       Hip
# 1118       SLvl            5            6       1958          1987     Gable
# 647      1Story            6            5       1953          1953       Hip
# 1441     1Story            6            5       2004          2004     Gable
# 186        SLvl            7            5       1990          1991     Gable
# 1341     1Story            6            5       2003          2004     Gable
# 1225       SLvl            6            8       1958          1958       Hip
# 1257     1Story            5            8       1922          1950     Gable
# 532      1Story            5            7       1955          2007     Gable
# 1330     1Story            8            5       2006          2006       Hip
# 580      1Story            6            6       1960          1987     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType MasVnrArea ExterQual  \
# 129   CompShg     Plywood     Plywood    BrkFace         85        TA
# 512   CompShg     VinylSd     VinylSd       None          0        TA
# 474   CompShg     CemntBd     CmentBd       None          0        Gd
# 402   CompShg     Wd Sdng     Wd Sdng       None          0        TA
# 407   CompShg     Wd Sdng     Plywood       None          0        TA
# 82    CompShg     VinylSd     VinylSd      Stone        468        TA
# 1220  CompShg     Wd Sdng     Wd Sdng       None          0        TA
# 568   CompShg     Wd Sdng     Wd Sdng       None          0        Gd
# 336   CompShg     VinylSd     VinylSd      Stone        200        Gd
# 1458  CompShg     MetalSd     MetalSd       None          0        TA
# 1118  CompShg     MetalSd     MetalSd       None          0        TA
# 647   CompShg     Wd Sdng     Wd Sdng      Stone        216        TA
# 1441  CompShg     VinylSd     VinylSd    BrkFace        147        Gd
# 186   CompShg     HdBoard     HdBoard       None          0        TA
# 1341  CompShg     VinylSd     VinylSd       None          0        TA
# 1225  CompShg     VinylSd     VinylSd    BrkFace         63        TA
# 1257  CompShg     Wd Sdng     Wd Sdng       None          0        TA
# 532   CompShg     VinylSd     VinylSd       None          0        TA
# 1330  CompShg     VinylSd     VinylSd      Stone        410        Gd
# 580   CompShg     Wd Sdng     Wd Sdng    BrkFace         85        TA
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 129         TA     CBlock       TA       TA           No          Rec
# 512         TA     CBlock       TA       TA           No          BLQ
# 474         TA      PConc       Gd       TA           Av          GLQ
# 402         TA      PConc       TA       TA           No          Unf
# 407         TA     BrkTil       Gd       TA           No          Unf
# 82          TA      PConc       Gd       TA           No          GLQ
# 1220        TA     CBlock       TA       TA           No          Rec
# 568         TA     CBlock       Gd       TA           Gd          GLQ
# 336         TA      PConc       Ex       TA           Gd          GLQ
# 1458        TA     CBlock       TA       TA           Mn          GLQ
# 1118        Gd     CBlock       TA       TA           No          Unf
# 647         TA     CBlock       TA       TA           Mn          Rec
# 1441        TA      PConc       Gd       TA           Av          GLQ
# 186         TA      PConc       Gd       TA           Av          GLQ
# 1341        TA      PConc       Gd       TA           No          GLQ
# 1225        Gd     CBlock       TA       TA           Av          GLQ
# 1257        TA      PConc       Fa       TA           No          Unf
# 532         TA       Slab  Missing  Missing      Missing      Missing
# 1330        TA      PConc       Gd       Gd           Av          Unf
# 580         TA     CBlock       TA       TA           No          BLQ
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 129          567          BLQ          28        413         1008    GasA
# 512          521          LwQ         174        169          864    GasA
# 474         1196          Unf           0        298         1494    GasA
# 402            0          Unf           0        672          672    GasA
# 407            0          Unf           0        840          840    GasA
# 82            33          Unf           0       1530         1563    GasA
# 1220         312          LwQ         600          0          912    GasA
# 568         1441          Unf           0         55         1496    GasA
# 336         1249          Unf           0        673         1922    GasA
# 1458          49          Rec        1029          0         1078    GasA
# 1118           0          Unf           0        533          533    GasA
# 647          500          Unf           0        594         1094    GasA
# 1441         697          Unf           0        151          848    GasA
# 186          611          Unf           0        577         1188    GasA
# 1341         814          Unf           0        300         1114    GasA
# 1225         507          Unf           0         81          588    GasA
# 1257           0          Unf           0        864          864    GasA
# 532            0      Missing           0          0            0    GasA
# 1330           0          Unf           0       1588         1588    GasA
# 580          594          Rec         219        331         1144    GasA
#
#      HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 129         TA          Y      FuseA      1053         0             0
# 512         TA          Y      SBrkr       864         0             0
# 474         Ex          Y      SBrkr      1652         0             0
# 402         Ex          Y      SBrkr       672         0             0
# 407         Ex          Y      SBrkr       840       840             0
# 82          Ex          Y      SBrkr      1563         0             0
# 1220        TA          Y      SBrkr       912         0             0
# 568         Ex          Y      SBrkr      1496       636             0
# 336         Ex          Y      SBrkr      1922         0             0
# 1458        Gd          Y      FuseA      1078         0             0
# 1118        TA          Y      SBrkr      1021       580             0
# 647         Ex          Y      SBrkr      1094         0             0
# 1441        Ex          Y      SBrkr       848         0             0
# 186         Ex          Y      SBrkr      1217         0             0
# 1341        Ex          Y      SBrkr      1114         0             0
# 1225        Ex          Y      SBrkr      1138         0             0
# 1257        Ex          Y      SBrkr       864         0             0
# 532         Ex          Y      SBrkr       827         0             0
# 1330        Ex          Y      SBrkr      1588         0             0
# 580         Ex          Y      SBrkr      1429         0             0
#
#       GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 129        1053             0             1         1         1             3
# 512         864             1             0         1         0             3
# 474        1652             1             0         2         0             2
# 402         672             0             0         1         0             2
# 407        1680             0             0         2         0             4
# 82         1563             0             0         2         0             3
# 1220        912             0             0         1         0             2
# 568        2132             1             0         1         1             1
# 336        1922             1             0         2         0             3
# 1458       1078             1             0         1         0             2
# 1118       1601             0             1         1         0             3
# 647        1094             0             0         1         0             3
# 1441        848             1             0         1         0             1
# 186        1217             1             0         2         0             3
# 1341       1114             1             0         1         0             3
# 1225       1138             0             1         1         0             3
# 1257        864             0             0         1         0             2
# 532         827             0             0         1         0             2
# 1330       1588             0             0         2         0             3
# 580        1429             0             1         1         0             3
#
#       KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 129              1          Ex             6        Typ           0
# 512              1          TA             5        Typ           0
# 474              1          Ex             6        Typ           0
# 402              1          TA             4        Typ           0
# 407              1          TA             8        Typ           0
# 82               1          Gd             6        Typ           1
# 1220             1          TA             5        Typ           0
# 568              1          Gd             5       Min2           1
# 336              1          Gd             8        Typ           1
# 1458             1          Gd             5        Typ           0
# 1118             1          TA             6       Min2           0
# 647              1          TA             5        Typ           2
# 1441             1          Gd             3        Typ           1
# 186              1          Gd             6        Typ           0
# 1341             1          Gd             6        Typ           0
# 1225             1          TA             6        Typ           0
# 1257             1          TA             4        Typ           0
# 532              1          TA             5        Mod           1
# 1330             1          Gd             7        Typ           1
# 580              1          Gd             7        Typ           2
#
#      FireplaceQu GarageType GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 129      Missing     2Types        1998          RFn           2         750
# 512      Missing     Detchd        1964          Unf           2         624
# 474      Missing     Attchd        2000          RFn           2         499
# 402      Missing     Detchd        1940          Unf           1         240
# 407      Missing     Attchd        1960          Unf           1         308
# 82            Gd     Attchd        2007          RFn           3         758
# 1220     Missing     Attchd        1964          Unf           1         288
# 568           Gd    BuiltIn        1983          Fin           2         612
# 336           Gd     Attchd        2005          Fin           3         676
# 1458     Missing     Attchd        1950          Unf           1         240
# 1118     Missing    BuiltIn        1958          RFn           1         300
# 647           Gd     Attchd        1953          RFn           2         495
# 1441          TA     Attchd        2004          RFn           2         420
# 186      Missing     Attchd        1990          Unf           2         497
# 1341     Missing     Detchd        2004          Unf           2         576
# 1225     Missing     Attchd        1958          RFn           1         264
# 1257     Missing    Missing     Missing      Missing           0           0
# 532           Po     Detchd        1967          Unf           1         392
# 1330          Gd     Attchd        2006          RFn           3         825
# 580           Gd     Attchd        1960          Unf           2         572
#
#      GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 129          TA         TA          Y           0           80              0
# 512          TA         TA          Y           0            0              0
# 474          TA         TA          Y          96           48              0
# 402          TA         TA          N         168            0              0
# 407          TA         TA          Y           0            0            160
# 82           TA         TA          Y         144           99              0
# 1220         TA         TA          Y           0            0              0
# 568          Gd         TA          Y         349           40              0
# 336          TA         TA          Y         178           51              0
# 1458         TA         TA          Y         366            0            112
# 1118         TA         TA          Y         280           34              0
# 647          TA         TA          Y           0            0              0
# 1441         TA         TA          Y         149            0              0
# 186          TA         TA          Y         168           27              0
# 1341         TA         TA          Y           0           78              0
# 1225         TA         TA          Y         224            0              0
# 1257    Missing    Missing          Y           0           96              0
# 532          TA         TA          Y           0            0              0
# 1330         TA         TA          Y         144           45              0
# 580          TA         TA          Y         216          110              0
#
#       3SsnPorch  ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  \
# 129         180            0         0  Missing     MnWw     Missing        0
# 512           0            0         0  Missing  Missing     Missing        0
# 474           0            0         0  Missing  Missing     Missing        0
# 402           0            0         0  Missing    GdPrv     Missing        0
# 407           0            0         0  Missing  Missing     Missing        0
# 82            0            0         0  Missing  Missing     Missing        0
# 1220          0            0         0  Missing  Missing     Missing        0
# 568           0            0         0  Missing  Missing     Missing        0
# 336           0            0         0  Missing  Missing     Missing        0
# 1458          0            0         0  Missing  Missing     Missing        0
# 1118          0            0         0  Missing  Missing     Missing        0
# 647           0          287         0  Missing  Missing     Missing        0
# 1441          0            0         0  Missing  Missing     Missing        0
# 186           0            0         0  Missing    GdPrv     Missing        0
# 1341          0            0         0  Missing  Missing     Missing        0
# 1225          0            0         0  Missing     MnWw     Missing        0
# 1257          0            0         0  Missing  Missing     Missing        0
# 532           0            0         0  Missing  Missing     Missing        0
# 1330          0            0         0  Missing  Missing     Missing        0
# 580           0            0         0  Missing  Missing     Missing        0
#
#       MoSold  YrSold SaleType SaleCondition  SalePrice  Great
# 129        7    2006       WD       Abnorml     150000  False
# 512        7    2006       WD        Normal     129900  False
# 474        8    2007       WD        Normal     251000  False
# 402        8    2008       WD        Normal     108000  False
# 407        3    2008       WD        Normal     177000   True
# 82        10    2008       WD        Normal     245000  False
# 1220      11    2006       WD       Abnorml     115000  False
# 568        9    2009       WD        Normal     316600  False
# 336        7    2007       WD        Normal     377426  False
# 1458       4    2010       WD        Normal     142125  False
# 1118      12    2008       WD        Normal     140000  False
# 647        6    2008       WD        Normal     155000  False
# 1441       5    2008       WD        Normal     149300  False
# 186        6    2009       WD        Normal     173000  False
# 1341       7    2008       WD        Normal     155000  False
# 1225       6    2007       WD        Normal     145000  False
# 1257       7    2009       WD        Normal      99900  False
# 532        4    2010       WD        Normal     107500  False
# 1330      12    2007       WD        Normal     227000  False
# 580        6    2007       WD        Normal     181900  False

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL          65     8450   Pave  Missing      Reg
# 1   2          20       RL          80     9600   Pave  Missing      Reg
# 2   3          60       RL          68    11250   Pave  Missing      IR1
# 3   4          70       RL          60     9550   Pave  Missing      IR1
# 4   5          60       RL          84    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Condition1 Condition2 BldgType  \
# 0         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 1         Lvl    AllPub       FR2       Gtl      Feedr       Norm     1Fam
# 2         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 3         Lvl    AllPub    Corner       Gtl       Norm       Norm     1Fam
# 4         Lvl    AllPub       FR2       Gtl       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
# 2     2Story            7            5       2001          2002     Gable
# 3     2Story            7            5       1915          1970     Gable
# 4     2Story            8            5       2000          2000     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace        196        Gd        TA
# 1  CompShg     MetalSd     MetalSd       None          0        TA        TA
# 2  CompShg     VinylSd     VinylSd    BrkFace        162        Gd        TA
# 3  CompShg     Wd Sdng     Wd Shng       None          0        TA        TA
# 4  CompShg     VinylSd     VinylSd    BrkFace        350        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0      PConc       Gd       TA           No          GLQ         706
# 1     CBlock       Gd       TA           Gd          ALQ         978
# 2      PConc       Gd       TA           Mn          GLQ         486
# 3     BrkTil       TA       Gd           No          ALQ         216
# 4      PConc       Gd       TA           Av          GLQ         655
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf           0        150          856    GasA        Ex
# 1          Unf           0        284         1262    GasA        Ex
# 2          Unf           0        434          920    GasA        Ex
# 3          Unf           0        540          756    GasA        Gd
# 4          Unf           0        490         1145    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
# 3          Y      SBrkr       961       756             0       1717
# 4          Y      SBrkr      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
# 1             0             1         2         0             3             1
# 2             1             0         2         1             3             1
# 3             1             0         1         0             3             1
# 4             1             0         2         1             4             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          Gd             8        Typ           0     Missing     Attchd
# 1          TA             6        Typ           1          TA     Attchd
# 2          Gd             6        Typ           1          TA     Attchd
# 3          Gd             7        Typ           1          Gd     Detchd
# 4          Gd             9        Typ           1          TA     Attchd
#
#   GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0        2003          RFn           2         548         TA         TA
# 1        1976          RFn           2         460         TA         TA
# 2        2001          RFn           2         608         TA         TA
# 3        1998          Unf           3         642         TA         TA
# 4        2000          RFn           3         836         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0           61              0          0            0
# 1          Y         298            0              0          0            0
# 2          Y           0           42              0          0            0
# 3          Y           0           35            272          0            0
# 4          Y         192           84              0          0            0
#
#    PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0         0  Missing  Missing     Missing        0       2    2008       WD
# 1         0  Missing  Missing     Missing        0       5    2007       WD
# 2         0  Missing  Missing     Missing        0       9    2008       WD
# 3         0  Missing  Missing     Missing        0       2    2006       WD
# 4         0  Missing  Missing     Missing        0      12    2008       WD
#
#   SaleCondition  SalePrice  Great
# 0        Normal     208500  False
# 1        Normal     181500  False
# 2        Normal     223500  False
# 3       Abnorml     140000  False
# 4        Normal     250000   True

# %%
df.shape
# Out:
# (1460, 81)

# %%
train = pd.merge(left=df, right=df)
train.head()
# Out:
#    Id  MSSubClass MSZoning LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL          65     8450   Pave  Missing      Reg
# 1   2          20       RL          80     9600   Pave  Missing      Reg
# 2   3          60       RL          68    11250   Pave  Missing      IR1
# 3   4          70       RL          60     9550   Pave  Missing      IR1
# 4   5          60       RL          84    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Condition1 Condition2 BldgType  \
# 0         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 1         Lvl    AllPub       FR2       Gtl      Feedr       Norm     1Fam
# 2         Lvl    AllPub    Inside       Gtl       Norm       Norm     1Fam
# 3         Lvl    AllPub    Corner       Gtl       Norm       Norm     1Fam
# 4         Lvl    AllPub       FR2       Gtl       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
# 2     2Story            7            5       2001          2002     Gable
# 3     2Story            7            5       1915          1970     Gable
# 4     2Story            8            5       2000          2000     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace        196        Gd        TA
# 1  CompShg     MetalSd     MetalSd       None          0        TA        TA
# 2  CompShg     VinylSd     VinylSd    BrkFace        162        Gd        TA
# 3  CompShg     Wd Sdng     Wd Shng       None          0        TA        TA
# 4  CompShg     VinylSd     VinylSd    BrkFace        350        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0      PConc       Gd       TA           No          GLQ         706
# 1     CBlock       Gd       TA           Gd          ALQ         978
# 2      PConc       Gd       TA           Mn          GLQ         486
# 3     BrkTil       TA       Gd           No          ALQ         216
# 4      PConc       Gd       TA           Av          GLQ         655
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf           0        150          856    GasA        Ex
# 1          Unf           0        284         1262    GasA        Ex
# 2          Unf           0        434          920    GasA        Ex
# 3          Unf           0        540          756    GasA        Gd
# 4          Unf           0        490         1145    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
# 3          Y      SBrkr       961       756             0       1717
# 4          Y      SBrkr      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
# 1             0             1         2         0             3             1
# 2             1             0         2         1             3             1
# 3             1             0         1         0             3             1
# 4             1             0         2         1             4             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          Gd             8        Typ           0     Missing     Attchd
# 1          TA             6        Typ           1          TA     Attchd
# 2          Gd             6        Typ           1          TA     Attchd
# 3          Gd             7        Typ           1          Gd     Detchd
# 4          Gd             9        Typ           1          TA     Attchd
#
#   GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0        2003          RFn           2         548         TA         TA
# 1        1976          RFn           2         460         TA         TA
# 2        2001          RFn           2         608         TA         TA
# 3        1998          Unf           3         642         TA         TA
# 4        2000          RFn           3         836         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0           61              0          0            0
# 1          Y         298            0              0          0            0
# 2          Y           0           42              0          0            0
# 3          Y           0           35            272          0            0
# 4          Y         192           84              0          0            0
#
#    PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0         0  Missing  Missing     Missing        0       2    2008       WD
# 1         0  Missing  Missing     Missing        0       5    2007       WD
# 2         0  Missing  Missing     Missing        0       9    2008       WD
# 3         0  Missing  Missing     Missing        0       2    2006       WD
# 4         0  Missing  Missing     Missing        0      12    2008       WD
#
#   SaleCondition  SalePrice  Great
# 0        Normal     208500  False
# 1        Normal     181500  False
# 2        Normal     223500  False
# 3       Abnorml     140000  False
# 4        Normal     250000   True

# %%
train = pd.merge(left=df, right=df)
train.shape
# Out:
# (1460, 81)

# %%
train['SalePrice'].value_counts()
# Out:
# 140000    20
# 135000    17
# 145000    14
# 155000    14
# 190000    13
#           ..
# 84900      1
# 424870     1
# 415298     1
# 62383      1
# 34900      1
# Name: SalePrice, Length: 663, dtype: int64

# %%
train['Great'].value_counts(normalize=True)
# Out:
# False    0.834247
# True     0.165753
# Name: Great, dtype: float64

# %%
train_wrangled = train.groupby('Id')['Great'].any().reset_index()
train_wrangled.head()
# Out:
#    Id  Great
# 0   1  False
# 1   2  False
# 2   3  False
# 3   4  False
# 4   5   True

# %%
train_wrangled.shape
# Out:
# (1460, 2)

# %%
train['Great'].value_counts(normalize=True)
# Out:
# False    0.834247
# True     0.165753
# Name: Great, dtype: float64

# %%
# Change column names: replace spaces with underscores

# %%
# Get Pandas Profiling Report

# %%
# Keep just the subset of data for the Tribeca neighborhood
# Check how many rows you have now. (Should go down from > 20k rows to 146)

# %%
# Q. What's the date range of these property sales in Tribeca?

# %%
# The Pandas Profiling Report showed that SALE_PRICE was read as strings
# Convert it to integers

# %%
# Q. What is the maximum SALE_PRICE in this dataset?

# %%
# Look at the row with the max SALE_PRICE

# %%
# Get value counts of TOTAL_UNITS
# Q. How many property sales were for multiple units?

# %%
# Keep only the single units

# %%
# Q. Now what is the max sales price? How many square feet does it have?

# %%
# Q. How often did $0 sales occur in this subset of the data?

# There's a glossary here: 
# https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page

# It says:
# A $0 sale indicates that there was a transfer of ownership without a 
# cash consideration. There can be a number of reasons for a $0 sale including 
# transfers of ownership from parents to children.

# %%
# Look at property sales for > 5,000 square feet
# Q. What is the highest square footage you see?

# %%
# What are the building class categories?
# How frequently does each occur?

# %%
# Keep subset of rows:
# Sale price more than $0, 
# Building class category = Condos - Elevator Apartments

# Check how many rows you have now. (Should be 106 rows.)

# %%
# Make a Plotly Express scatter plot of GROSS_SQUARE_FEET vs SALE_PRICE

# %%
# Add an OLS (Ordinary Least Squares) trendline,
# to see how the outliers influence the "line of best fit"

# %%
# Look at sales for more than $35 million

# All are at 70 Vestry Street
# All but one have the same SALE_PRICE & SALE_DATE
# Was the SALE_PRICE for each? Or in total?
# Is this dirty data?

# %%
# Make a judgment call:
# Keep rows where sale price was < $35 million

# Check how many rows you have now. (Should be down to 90 rows.)

# %%
# Now that you've removed outliers,
# Look again at a scatter plot with OLS (Ordinary Least Squares) trendline

# %%
# Select these columns, then write to a csv file named tribeca.csv. Don't include the index.
